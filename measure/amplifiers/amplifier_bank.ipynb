# %%
import skrf as rf
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# %%
swl88 = rf.Network('amplifier_data/amplifier_swl_88_6176.s2p')
ifs4=rf.Network('amplifier_data/amplifier_ifs4_00101275_45_10p_4.s2p')
sa9=rf.Network('amplifier_data/amplifier_sa9_1218_sn0013.s2p');
amf3d=rf.Network('amplifier_data/amplifier_amf_3d_00300600_60_24p.s2p')
amp81413=rf.Network('amplifier_data/amplifier_81413_sn1015.s2p')
apt=rf.Network('amplifier_data/amplifier_apt_4064m.s2p')
km=rf.Network('amplifier_data/amplifier_km574302.s2p')
swl88.plot_s_db(n=0, m=1)
ifs4.plot_s_db(n=0, m=1)
sa9.plot_s_db(n=0, m=1)
amf3d.plot_s_db(n=0, m=1)
amp81413.plot_s_db(n=0, m=1)
apt.plot_s_db(n=0, m=1)
km.plot_s_db(n=0, m=1)
plt.ylim([0, 45])
plt.grid()
