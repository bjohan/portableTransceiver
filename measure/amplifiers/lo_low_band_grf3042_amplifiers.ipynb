# %%
import sys
sys.path.append("gpib_instrument_control")
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]
import skrf as rf
import scipy.io as sio
import gpib_instrument_control.hp_8700_series_vna
import gpib_instrument_control.vna_fixture
import gpib_instrument_control.switch_calkit
import serial
import time

vna = gpib_instrument_control.hp_8700_series_vna.Hp8753A()
vna.outputPower(-20)
vna.setIfBandwidth(300)
print("If bandwidth is", vna.ifBandwidth())
#calkit = gpib_instrument_control.switch_calkit.SwitchCalkit(None, serialPortPath='/dev/ttyUSB0')
calkit = None
#ampBank = serial.Serial('/dev/ttyUSB1', 115200)
fixture = gpib_instrument_control.vna_fixture.VnaFixture(vna, calkit, 130e6, 20e9, 1e6, 'measured_stds_low_band/', 'data/cal_stds/')
# Out:
# b'HEWLETT PACKARD,8703A,0,1.00\n'
# If bandwidth is 300.0
# ...
# Success
# ...
# Success
# ...
# Success
# ...
# Success

# %%
ntwAmp = fixture.calibratedMeasure()
#ntw.write_touchstone('amplifier_bank_data/amplifier%d.s2p'%(amp))
ntwAmp.plot_s_db()
plt.grid(True)
plt.figure()
ntwAmp.plot_s_db();
plt.xlim([0,9e9])
plt.grid(True)

# %%
#Amplifier with new pullup resistor on input, 0402 1k8 instead of 0603 1k68
ntwAmp3 = fixture.calibratedMeasure()
#ntw.write_touchstone('amplifier_bank_data/amplifier%d.s2p'%(amp))
ntwAmp3.plot_s_db()
plt.grid(True)
plt.figure()
ntwAmp3.plot_s_db();
plt.xlim([0,9e9])
plt.grid(True)

# %%
#Amplifier with new pullup resistor on input, 0402 1k8 instead of 0603 1k68. Previous DC blocks moved to be  used as decoupling. New DC blocks 82 PF
ntwAmp4 = fixture.calibratedMeasure()
#ntw.write_touchstone('amplifier_bank_data/amplifier%d.s2p'%(amp))
ntwAmp4.plot_s_db()
plt.grid(True)
plt.figure()
ntwAmp4.plot_s_db();
plt.xlim([0,9e9])
plt.grid(True)

# %%
#Amplifier with new pullup resistor on input, 0402 1k8 instead of 0603 1k68. Previous DC blocks moved to be  used as decoupling. New DC blocks 82 PF. Resoldered rivets on back side
ntwAmp4 = fixture.calibratedMeasure()
#ntw.write_touchstone('amplifier_bank_data/amplifier%d.s2p'%(amp))
ntwAmp4.plot_s_db()
plt.grid(True)
plt.figure()
ntwAmp4.plot_s_db();
plt.xlim([0,9e9])
plt.grid(True)

# %%
#Amplifier with new pullup resistor on input, 0402 1k8 instead of 0603 1k68. Previous DC blocks moved to be  used as decoupling. New DC blocks 82 PF, resoldered again
ntwAmp5 = fixture.calibratedMeasure()
#ntw.write_touchstone('amplifier_bank_data/amplifier%d.s2p'%(amp))
ntwAmp5.plot_s_db()
plt.grid(True)
plt.figure()
ntwAmp5.plot_s_db();
plt.xlim([0,9e9])
plt.grid(True)

# %%
#Amplifier with new pullup resistor on input, 0402 1k8 instead of 0603 1k68. Previous DC blocks moved to be  used as decoupling.
# New DC blocks 82 PF, resoldered again, back in box
ntwAmp6 = fixture.calibratedMeasure()
#ntw.write_touchstone('amplifier_bank_data/amplifier%d.s2p'%(amp))
ntwAmp6.plot_s_db()
plt.grid(True)
plt.figure()
ntwAmp6.plot_s_db();
plt.xlim([0,9e9])
plt.grid(True)

# %%
#ntw = fixture.calibratedMeasure()
#ntw.write_touchstone('amplifier_bank_data/amplifier%d.s2p'%(amp))
ntw.plot_s_db()
plt.grid(True)
plt.ylim([-3, 3])
# Out:
# (-3.0, 3.0)

# %%
ntw.plot_s_db()
